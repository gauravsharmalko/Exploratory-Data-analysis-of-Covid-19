# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
covid_df = pd.read_csv('Covid_India.csv')

# %%
type(covid_df)
# Out:
# pandas.core.frame.DataFrame

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1196 entries, 0 to 1195
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1196 non-null   object
#  1   new_cases   1193 non-null   float64
#  2   new_deaths  1196 non-null   int64
#  3   new_tests   795 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 37.5+ KB

# %%
covid_df.describe()
# Out:
#            new_cases   new_deaths     new_tests
# count    1193.000000  1196.000000  7.950000e+02
# mean    37697.865884   444.571070  1.055093e+06
# std     70423.776876   801.097835  1.379855e+06
# min         0.000000     0.000000  1.570000e+02
# 25%      2208.000000    18.000000  4.985255e+05
# 50%     12729.000000   151.500000  1.014079e+06
# 75%     40425.000000   497.500000  1.411204e+06
# max    414188.000000  6148.000000  3.585563e+07

# %%
covid_df.columns
# Out:
# Index(['date', 'new_cases', 'new_deaths', 'new_tests'], dtype='object')

# %%
covid_df.shape
# Out:
# (1196, 4)

# %%
covid_df.tail()
# Out:
#             date  new_cases  new_deaths  new_tests
# 1191  05-05-2023     3611.0          36        NaN
# 1192  06-05-2023     2961.0          17        NaN
# 1193  07-05-2023     2380.0          21        NaN
# 1194  08-05-2023     1839.0          12        NaN
# 1195  09-05-2023     1331.0          15        NaN

# %%
covid_df['new_cases']
# Out:
# 0          1.0
# 1          4.0
# 2          0.0
# 3          NaN
# 4          1.0
#          ...
# 1191    3611.0
# 1192    2961.0
# 1193    2380.0
# 1194    1839.0
# 1195    1331.0
# Name: new_cases, Length: 1196, dtype: float64

# %%
covid_df['new_deaths']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 1191    36
# 1192    17
# 1193    21
# 1194    12
# 1195    15
# Name: new_deaths, Length: 1196, dtype: int64

# %%
covid_df['new_tests']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1191   NaN
# 1192   NaN
# 1193   NaN
# 1194   NaN
# 1195   NaN
# Name: new_tests, Length: 1196, dtype: float64

# %%
type(covid_df['new_cases'])
# Out:
# pandas.core.series.Series

# %%
covid_df['new_cases'][246]
# Out:
# 81484.0

# %%
covid_df['new_tests'][243]
# Out:
# 1142811.0

# %%
covid_df.at[246, 'new_cases']
# Out:
# 81484.0

# %%
covid_df.at[243, 'new_tests']
# Out:
# 1142811.0

# %%
covid_df.loc[200:250]
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 200 2020-08-17    57981.0         941   731697.0  2020      8   17        0  \
# 201 2020-08-18    55079.0         876   899864.0  2020      8   18        1
# 202 2020-08-19    64531.0        1092   801518.0  2020      8   19        2
# 203 2020-08-20    69652.0         977   918470.0  2020      8   20        3
# 204 2020-08-21    68898.0         983   805985.0  2020      8   21        4
# 205 2020-08-22    69878.0         945  1023836.0  2020      8   22        5
# 206 2020-08-23    69239.0         912   801147.0  2020      8   23        6
# 207 2020-08-24    61408.0         836   609917.0  2020      8   24        0
# 208 2020-08-25    60975.0         848   925383.0  2020      8   25        1
# 209 2020-08-26    67151.0        1059   823992.0  2020      8   26        2
# 210 2020-08-27    75760.0        1023   924998.0  2020      8   27        3
# ...

# %%
covid_df.loc[345]
# Out:
# date            2021-01-09 00:00:00
# new_cases                   18222.0
# new_deaths                      228
# new_tests                  916951.0
# year                           2021
# month                             1
# day                               9
# weekday                           5
# total_cases              10431644.0
# total_deaths                 150798
# total_tests             178180754.0
# location                      India
# Name: 345, dtype: object

# %%
covid_df.new_cases
# Out:
# 0          1.0
# 1          4.0
# 2          0.0
# 3          NaN
# 4          1.0
#          ...
# 1191    3611.0
# 1192    2961.0
# 1193    2380.0
# 1194    1839.0
# 1195    1331.0
# Name: new_cases, Length: 1196, dtype: float64

# %%
covid_df[['date', 'new_cases']]
# Out:
#             date  new_cases
# 0     30-01-2020        1.0
# 1     31-01-2020        4.0
# 2     01-02-2020        0.0
# 3     02-02-2020        NaN
# 4     03-02-2020        1.0
# ...          ...        ...
# 1191  05-05-2023     3611.0
# 1192  06-05-2023     2961.0
# 1193  07-05-2023     2380.0
# 1194  08-05-2023     1839.0
# 1195  09-05-2023     1331.0
#
# [1196 rows x 2 columns]

# %%
covid_df_copy = covid_df.copy()

# %%
covid_df_copy
# Out:
#             date  new_cases  new_deaths  new_tests
# 0     30-01-2020        1.0           0        NaN
# 1     31-01-2020        4.0           0        NaN
# 2     01-02-2020        0.0           0        NaN
# 3     02-02-2020        NaN           0        NaN
# 4     03-02-2020        1.0           0        NaN
# ...          ...        ...         ...        ...
# 1191  05-05-2023     3611.0          36        NaN
# 1192  06-05-2023     2961.0          17        NaN
# 1193  07-05-2023     2380.0          21        NaN
# 1194  08-05-2023     1839.0          12        NaN
# 1195  09-05-2023     1331.0          15        NaN
#
# [1196 rows x 4 columns]

# %%
covid_df.loc[247]
# Out:
# date          03-10-2020
# new_cases        79476.0
# new_deaths          1069
# new_tests      1132675.0
# Name: 247, dtype: object

# %%
type(covid_df.loc[247])
# Out:
# pandas.core.series.Series

# %%
covid_df.head()
# Out:
#          date  new_cases  new_deaths  new_tests
# 0  30-01-2020        1.0           0        NaN
# 1  31-01-2020        4.0           0        NaN
# 2  01-02-2020        0.0           0        NaN
# 3  02-02-2020        NaN           0        NaN
# 4  03-02-2020        1.0           0        NaN

# %%
covid_df.tail(2)
# Out:
#             date  new_cases  new_deaths  new_tests
# 1194  08-05-2023     1839.0          12        NaN
# 1195  09-05-2023     1331.0          15        NaN

# %%
covid_df.at[0, 'new_tests']
# Out:
# nan

# %%
type(covid_df.at[0, 'new_tests'])
# Out:
# numpy.float64

# %%
covid_df.new_tests.first_valid_index()
# Out:
# 49

# %%
covid_df.new_tests[49]
# Out:
# 191.0

# %%
covid_df.loc[47:53]
# Out:
#           date  new_cases  new_deaths  new_tests
# 47  17-03-2020       23.0           1        NaN
# 48  18-03-2020       14.0           0        NaN
# 49  19-03-2020       22.0           1      191.0
# 50  20-03-2020       50.0           0     1060.0
# 51  21-03-2020       60.0           0     1325.0
# 52  22-03-2020       77.0           3     1298.0
# 53  23-03-2020       74.0           2     3708.0

# %%
covid_df.sample(8).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_e316b_row0_col1, #T_e316b_row0_col2, #T_e316b_row7_col3 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_e316b_row0_col3 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_e316b_row1_col1 {
#   background-color: #e22e27;
#   color: #f1f1f1;
# }
# #T_e316b_row1_col2 {
#   background-color: #fb6c4c;
#   color: #f1f1f1;
# }
# #T_e316b_row1_col3 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_e316b_row2_col1 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_e316b_row2_col2 {
#   background-color: #f96044;
#   color: #f1f1f1;
# }
# #T_e316b_row2_col3 {
#   background-color: #fa6648;
#   color: #f1f1f1;
# }
# #T_e316b_row3_col1, #T_e316b_row3_col2, #T_e316b_row3_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e316b_row4_col1 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_e316b_row4_col2, #T_e316b_row6_col3 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# ...

# %%
total_cases = covid_df.new_cases.sum()
total_deaths = covid_df.new_deaths.sum()

# %%
print("The number of reported cases is {} and the number of reported deaths is {}" .format(int(total_cases), int(total_deaths)))
# Out:
# The number of reported cases is 44973554 and the number of reported deaths is 531707

# %%
death_rate = (covid_df.new_deaths.sum() / covid_df.new_cases.sum()) * 100

# %%
print("The overall reported death rate in India is {:.2f} %" .format(death_rate))
# Out:
# The overall reported death rate in India is 1.18 %

# %%
total_tests = covid_df.new_tests.sum()

# %%
total_tests
# Out:
# 838798638.0

# %%
positive_rate = (total_cases / total_tests) * 100

# %%
print('{:.2f}% of tests in India led to a positive diagnosis.' .format(positive_rate))
# Out:
# 5.36% of tests in India led to a positive diagnosis.

# %%
high_new_cases = covid_df.new_cases > 10000

# %%
high_new_cases
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1191    False
# 1192    False
# 1193    False
# 1194    False
# 1195    False
# Name: new_cases, Length: 1196, dtype: bool

# %%
covid_df[high_new_cases]
# Out:
#             date  new_cases  new_deaths  new_tests
# 134   12-06-2020    10956.0         396   150305.0
# 135   13-06-2020    11458.0         386   143737.0
# 136   14-06-2020    11929.0         311   151432.0
# 137   15-06-2020    11502.0         325   115519.0
# 138   16-06-2020    10667.0         380   146936.0
# ...          ...        ...         ...        ...
# 1175  19-04-2023    10542.0          38        NaN
# 1176  20-04-2023    12591.0          40        NaN
# 1177  21-04-2023    11692.0          28        NaN
# 1178  22-04-2023    12193.0          42        NaN
# 1179  23-04-2023    10112.0          29        NaN
#
# [659 rows x 4 columns]

# %%
covid_df[high_new_cases].sample(10)
# Out:
#            date  new_cases  new_deaths  new_tests
# 757  25-02-2022    13166.0         302        NaN
# 536  19-07-2021    38164.0         499  1463593.0
# 425  30-03-2021    56211.0         271   785864.0
# 329  24-12-2020    24712.0         312  1039645.0
# 251  07-10-2020    72049.0         986  1199857.0
# 242  28-09-2020    82170.0        1039   709394.0
# 297  22-11-2020    45209.0         501  1075326.0
# 451  25-04-2021   349691.0        2767  1719588.0
# 353  17-01-2021    15144.0         181   779377.0
# 387  20-02-2021    13993.0         101   786618.0

# %%
high_cases_df = covid_df[covid_df.new_cases > 10000]

# %%
high_cases_df
# Out:
#             date  new_cases  new_deaths  new_tests
# 134   12-06-2020    10956.0         396   150305.0
# 135   13-06-2020    11458.0         386   143737.0
# 136   14-06-2020    11929.0         311   151432.0
# 137   15-06-2020    11502.0         325   115519.0
# 138   16-06-2020    10667.0         380   146936.0
# ...          ...        ...         ...        ...
# 1175  19-04-2023    10542.0          38        NaN
# 1176  20-04-2023    12591.0          40        NaN
# 1177  21-04-2023    11692.0          28        NaN
# 1178  22-04-2023    12193.0          42        NaN
# 1179  23-04-2023    10112.0          29        NaN
#
# [659 rows x 4 columns]

# %%
from IPython.display import display
with pd.option_context('display.max_rows', 100):
    display(covid_df[covid_df.new_cases > 10000])
# Out:
#             date  new_cases  new_deaths  new_tests
# 134   12-06-2020    10956.0         396   150305.0
# 135   13-06-2020    11458.0         386   143737.0
# 136   14-06-2020    11929.0         311   151432.0
# 137   15-06-2020    11502.0         325   115519.0
# 138   16-06-2020    10667.0         380   146936.0
# ...          ...        ...         ...        ...
# 1175  19-04-2023    10542.0          38        NaN
# 1176  20-04-2023    12591.0          40        NaN
# 1177  21-04-2023    11692.0          28        NaN
# 1178  22-04-2023    12193.0          42        NaN
# 1179  23-04-2023    10112.0          29        NaN
#
# [659 rows x 4 columns]

# %%
positive_rate
# Out:
# 5.361662735556325

# %%
high_ratio_df = covid_df[covid_df.new_cases / covid_df.new_tests > positive_rate]

# %%
high_ratio_df
# Out:
# Empty DataFrame
# Columns: [date, new_cases, new_deaths, new_tests]
# Index: []

# %%
covid_df.new_cases / covid_df.new_tests
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1191   NaN
# 1192   NaN
# 1193   NaN
# 1194   NaN
# 1195   NaN
# Length: 1196, dtype: float64

# %%
covid_df['positive_rate'] = covid_df.new_cases / covid_df.new_tests

# %%
covid_df.sample(10)
# Out:
#             date  new_cases  new_deaths  new_tests  positive_rate
# 706   05-01-2022    58097.0         534  1388647.0       0.041837
# 435   09-04-2021   131968.0         780  1364205.0       0.096736
# 10    09-02-2020        0.0           0        NaN            NaN
# 716   15-01-2022   268833.0         402  1613740.0       0.166590
# 1038  03-12-2022      253.0           3        NaN            NaN
# 930   17-08-2022     9062.0          36        NaN            NaN
# 1079  13-01-2023      174.0           2        NaN            NaN
# 868   16-06-2022    12213.0          11   519419.0       0.023513
# 879   27-06-2022    17073.0          21        NaN            NaN
# 310   05-12-2020    36652.0         512  1157763.0       0.031658

# %%
covid_df.drop(columns = ['positive_rate'], inplace = True)

# %%
covid_df
# Out:
#             date  new_cases  new_deaths  new_tests
# 0     30-01-2020        1.0           0        NaN
# 1     31-01-2020        4.0           0        NaN
# 2     01-02-2020        0.0           0        NaN
# 3     02-02-2020        NaN           0        NaN
# 4     03-02-2020        1.0           0        NaN
# ...          ...        ...         ...        ...
# 1191  05-05-2023     3611.0          36        NaN
# 1192  06-05-2023     2961.0          17        NaN
# 1193  07-05-2023     2380.0          21        NaN
# 1194  08-05-2023     1839.0          12        NaN
# 1195  09-05-2023     1331.0          15        NaN
#
# [1196 rows x 4 columns]

# %%
covid_df.sort_values('new_cases', ascending=False).head(10)
# Out:
#            date  new_cases  new_deaths  new_tests
# 463  07-05-2021   414188.0        3915  1826490.0
# 462  06-05-2021   412262.0        3980  1923131.0
# 465  09-05-2021   403738.0        4092  1865428.0
# 457  01-05-2021   401993.0        3523  1945299.0
# 464  08-05-2021   401078.0        4187  1808344.0
# 458  02-05-2021   392488.0        3689  1804954.0
# 456  30-04-2021   386452.0        3498  1920107.0
# 461  05-05-2021   382315.0        3780  1541299.0
# 455  29-04-2021   379257.0        3645  1768190.0
# 459  03-05-2021   368147.0        3417  1504698.0

# %%
covid_df.sort_values('new_deaths', ascending=False).head(10)
# Out:
#            date  new_cases  new_deaths  new_tests
# 497  10-06-2021    94052.0        6148  2004690.0
# 475  19-05-2021   267334.0        4529  2008296.0
# 480  24-05-2021   222315.0        4454  1928127.0
# 474  18-05-2021   263533.0        4329  1869223.0
# 477  21-05-2021   259551.0        4209  2061683.0
# 468  12-05-2021   348421.0        4205  1983804.0
# 478  22-05-2021   257299.0        4194  2066285.0
# 464  08-05-2021   401078.0        4187  1808344.0
# 482  26-05-2021   208921.0        4157  2217320.0
# 469  13-05-2021   362727.0        4120  1864594.0

# %%
covid_df.sort_values('new_cases').head(10)
# Out:
#           date  new_cases  new_deaths  new_tests
# 15  14-02-2020        0.0           0        NaN
# 28  27-02-2020        0.0           0        NaN
# 27  26-02-2020        0.0           0        NaN
# 26  25-02-2020        0.0           0        NaN
# 25  24-02-2020        0.0           0        NaN
# 24  23-02-2020        0.0           0        NaN
# 23  22-02-2020        0.0           0        NaN
# 22  21-02-2020        0.0           0        NaN
# 21  20-02-2020        0.0           0        NaN
# 20  19-02-2020        0.0           0        NaN

# %%
covid_df.loc[169:175]
# Out:
#            date  new_cases  new_deaths  new_tests
# 169  17-07-2020    34956.0         687   333228.0
# 170  18-07-2020    34884.0         671   361024.0
# 171  19-07-2020    38902.0         543   358127.0
# 172  20-07-2020    40425.0         681   256039.0
# 173  21-07-2020    37148.0         587   333395.0
# 174  22-07-2020    37724.0         648   343243.0
# 175  23-07-2020    45720.0        1129   350823.0

# %%
covid_df.date
# Out:
# 0       30-01-2020
# 1       31-01-2020
# 2       01-02-2020
# 3       02-02-2020
# 4       03-02-2020
#            ...
# 1191    05-05-2023
# 1192    06-05-2023
# 1193    07-05-2023
# 1194    08-05-2023
# 1195    09-05-2023
# Name: date, Length: 1196, dtype: object

# %%
covid_df['date'] = pd.to_datetime(covid_df.date)
# Out:
# C:\Users\mrgau\AppData\Local\Temp\ipykernel_9528\928678298.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   covid_df['date'] = pd.to_datetime(covid_df.date)

# %%
covid_df['date']
# Out:
# 0      2020-01-30
# 1      2020-01-31
# 2      2020-02-01
# 3      2020-02-02
# 4      2020-02-03
#           ...
# 1191   2023-05-05
# 1192   2023-05-06
# 1193   2023-05-07
# 1194   2023-05-08
# 1195   2023-05-09
# Name: date, Length: 1196, dtype: datetime64[ns]

# %%
covid_df['year'] = pd.DatetimeIndex(covid_df.date).year
covid_df['month'] = pd.DatetimeIndex(covid_df.date).month
covid_df['day'] = pd.DatetimeIndex(covid_df.date).day
covid_df['weekday'] = pd.DatetimeIndex(covid_df.date).weekday

# %%
covid_df.tail()
# Out:
#            date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 1191 2023-05-05     3611.0          36        NaN  2023      5    5        4
# 1192 2023-05-06     2961.0          17        NaN  2023      5    6        5
# 1193 2023-05-07     2380.0          21        NaN  2023      5    7        6
# 1194 2023-05-08     1839.0          12        NaN  2023      5    8        0
# 1195 2023-05-09     1331.0          15        NaN  2023      5    9        1

# %%
# Query the rows for May
covid_df_may = covid_df[covid_df.month == 5]

# Extract the subset of columns to be aggregated
covid_df_may_metrics = covid_df_may[['new_cases', 'new_deaths', 'new_tests']]

# Get the column-wise sum
covid_may_totals = covid_df_may_metrics.sum()

# %%
covid_may_totals
# Out:
# new_cases      9543285.0
# new_deaths      125861.0
# new_tests     70272029.0
# dtype: float64

# %%
type(covid_may_totals)
# Out:
# pandas.core.series.Series

# %%
covid_df[covid_df.month == 5][['new_cases', 'new_deaths', 'new_tests']].sum()
# Out:
# new_cases      9543285.0
# new_deaths      125861.0
# new_tests     70272029.0
# dtype: float64

# %%
# Overall average
covid_df.new_cases.mean()
# Out:
# 37697.86588432523

# %%
# Average for Sundays
covid_df[covid_df.weekday == 6].new_cases.mean()
# Out:
# 39022.82941176471

# %%
covid_month_df = covid_df.groupby('month')[['new_cases', 'new_deaths', 'new_tests']].sum()

# %%
covid_month_df
# Out:
#        new_cases  new_deaths   new_tests
# month
# 1      6947550.0       19544  71833952.0
# 2      1975830.0       21601  55960118.0
# 3      1183575.0       12831  45836883.0
# 4      6926467.0       50244  90775423.0
# 5      9543285.0      125861  70272029.0
# 6      2994088.0       81569  78189850.0
# 7      2890822.0       45451  66551310.0
# 8      3545844.0       44989  78589004.0
# 9      3734532.0       43285  75953381.0
# 10     2510961.0       34663  73962811.0
# 11     1628598.0       27888  64567845.0
# 12     1092002.0       23781  66306032.0

# %%
covid_month_mean_df = covid_df.groupby('month')[['new_cases', 'new_deaths', 'new_tests']].mean()

# %%
covid_month_mean_df
# Out:
#           new_cases   new_deaths     new_tests
# month
# 1      73132.105263   205.726316  1.197233e+06
# 2      17641.339286   191.159292  1.036298e+06
# 3       9622.560976   103.475806  7.051828e+05
# 4      57720.558333   418.700000  1.107017e+06
# 5      93561.617647  1233.931373  7.895734e+05
# 6      33267.644444   906.322222  9.653068e+05
# 7      31084.107527   488.720430  1.073408e+06
# 8      38127.354839   483.752688  1.267565e+06
# 9      41494.800000   480.944444  1.309541e+06
# 10     26999.580645   372.720430  1.192949e+06
# 11     18298.853933   309.866667  1.076131e+06
# 12     11741.956989   255.709677  1.105101e+06

# %%
covid_df['total_cases'] = covid_df.new_cases.cumsum()

# %%
covid_df['total_deaths'] = covid_df.new_deaths.cumsum()

# %%
covid_df['total_tests'] = covid_df.new_tests.cumsum()

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0    2020-01-30        1.0           0        NaN  2020      1   30        3  \
# 1    2020-01-31        4.0           0        NaN  2020      1   31        4
# 2    2020-02-01        0.0           0        NaN  2020      2    1        5
# 3    2020-02-02        NaN           0        NaN  2020      2    2        6
# 4    2020-02-03        1.0           0        NaN  2020      2    3        0
# ...         ...        ...         ...        ...   ...    ...  ...      ...
# 1191 2023-05-05     3611.0          36        NaN  2023      5    5        4
# 1192 2023-05-06     2961.0          17        NaN  2023      5    6        5
# 1193 2023-05-07     2380.0          21        NaN  2023      5    7        6
# 1194 2023-05-08     1839.0          12        NaN  2023      5    8        0
# 1195 2023-05-09     1331.0          15        NaN  2023      5    9        1
#
#       total_cases  total_deaths  total_tests
# ...

# %%
from urllib.request import urlretrieve
urlretrieve('https://gist.githubusercontent.com/aakashns/8684589ef4f266116cdce023377fc9c8/raw/99ce3826b2a9d1e6d0bde7e9e559fc8b6e9ac88b/locations.csv', 'locations.csv')
# Out:
# ('locations.csv', <http.client.HTTPMessage at 0x1fa8cbf4d50>)

# %%
locations_df = pd.read_csv('locations.csv')

# %%
locations_df.sample(12).style.background_gradient(cmap='twilight_shifted')
# Out:
# <style type="text/css">
# #T_fbd4b_row0_col2 {
#   background-color: #361141;
#   color: #f1f1f1;
# }
# #T_fbd4b_row0_col3, #T_fbd4b_row1_col2, #T_fbd4b_row2_col5, #T_fbd4b_row3_col2, #T_fbd4b_row8_col4, #T_fbd4b_row11_col2 {
#   background-color: #301437;
#   color: #f1f1f1;
# }
# #T_fbd4b_row0_col4 {
#   background-color: #4d1443;
#   color: #f1f1f1;
# }
# #T_fbd4b_row0_col5, #T_fbd4b_row10_col4 {
#   background-color: #5f64b5;
#   color: #f1f1f1;
# }
# #T_fbd4b_row1_col3 {
#   background-color: #ded2d2;
#   color: #000000;
# }
# #T_fbd4b_row1_col4 {
#   background-color: #c4ced4;
#   color: #000000;
# }
# #T_fbd4b_row1_col5 {
#   background-color: #562284;
#   color: #f1f1f1;
# }
# #T_fbd4b_row2_col2, #T_fbd4b_row7_col5 {
#   background-color: #511b77;
#   color: #f1f1f1;
# }
# #T_fbd4b_row2_col3 {
#   background-color: #6b8cbf;
#   color: #f1f1f1;
# }
# #T_fbd4b_row2_col4 {
#   background-color: #ca9c80;
#   color: #f1f1f1;
# }
# #T_fbd4b_row3_col3 {
# ...

# %%
locations_df[locations_df.location == "India"]
# Out:
#    location continent    population  life_expectancy
# 90    India      Asia  1.380004e+09            69.66  \
#
#     hospital_beds_per_thousand  gdp_per_capita
# 90                        0.53        6426.674

# %%
covid_df['location'] = "India"

# %%
covid_df.sample(12)
# Out:
#            date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 459  2021-05-03   368147.0        3417  1504698.0  2021      5    3        0  \
# 148  2020-06-26    17296.0         407   215446.0  2020      6   26        4
# 547  2021-07-30    44230.0         555  2020950.0  2021      7   30        4
# 767  2022-03-07     4362.0          66   612926.0  2022      3    7        0
# 399  2021-03-04    17407.0          89   775631.0  2021      3    4        3
# 1030 2022-11-25      347.0           3        NaN  2022     11   25        4
# 793  2022-04-02     1260.0          83   528021.0  2022      4    2        5
# 274  2020-10-30    48648.0         563  1164648.0  2020     10   30        4
# 203  2020-08-20    69652.0         977   918470.0  2020      8   20        3
# 827  2022-05-06     3545.0          27   465918.0  2022      5    6        4
# 752  2022-02-20    19968.0         673  1187766.0  2022      2   20        6
# ...

# %%
merged_df = covid_df.merge(locations_df, on="location")

# %%
merged_df
# Out:
#            date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0    2020-01-30        1.0           0        NaN  2020      1   30        3  \
# 1    2020-01-31        4.0           0        NaN  2020      1   31        4
# 2    2020-02-01        0.0           0        NaN  2020      2    1        5
# 3    2020-02-02        NaN           0        NaN  2020      2    2        6
# 4    2020-02-03        1.0           0        NaN  2020      2    3        0
# ...         ...        ...         ...        ...   ...    ...  ...      ...
# 1191 2023-05-05     3611.0          36        NaN  2023      5    5        4
# 1192 2023-05-06     2961.0          17        NaN  2023      5    6        5
# 1193 2023-05-07     2380.0          21        NaN  2023      5    7        6
# 1194 2023-05-08     1839.0          12        NaN  2023      5    8        0
# 1195 2023-05-09     1331.0          15        NaN  2023      5    9        1
#
# ...

# %%
merged_df['cases_per_million'] = merged_df.total_cases * 1e6 / merged_df.population

# %%
merged_df['deaths_per_million'] = merged_df.total_deaths * 1e6 / merged_df.population

# %%
merged_df['tests_per_million'] = merged_df.total_tests * 1e6 / merged_df.population

# %%
merged_df
# Out:
#            date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0    2020-01-30        1.0           0        NaN  2020      1   30        3  \
# 1    2020-01-31        4.0           0        NaN  2020      1   31        4
# 2    2020-02-01        0.0           0        NaN  2020      2    1        5
# 3    2020-02-02        NaN           0        NaN  2020      2    2        6
# 4    2020-02-03        1.0           0        NaN  2020      2    3        0
# ...         ...        ...         ...        ...   ...    ...  ...      ...
# 1191 2023-05-05     3611.0          36        NaN  2023      5    5        4
# 1192 2023-05-06     2961.0          17        NaN  2023      5    6        5
# 1193 2023-05-07     2380.0          21        NaN  2023      5    7        6
# 1194 2023-05-08     1839.0          12        NaN  2023      5    8        0
# 1195 2023-05-09     1331.0          15        NaN  2023      5    9        1
#
# ...

# %%
result_df = merged_df[['date',
                       'new_cases', 
                       'total_cases', 
                       'new_deaths', 
                       'total_deaths', 
                       'new_tests', 
                       'total_tests', 
                       'cases_per_million', 
                       'deaths_per_million', 
                       'tests_per_million']]

# %%
result_df.sample(5).style.background_gradient(cmap='gist_ncar')
# Out:
# <style type="text/css">
# #T_8753c_row0_col1 {
#   background-color: #c11fff;
#   color: #f1f1f1;
# }
# #T_8753c_row0_col2, #T_8753c_row0_col7 {
#   background-color: #003a35;
#   color: #f1f1f1;
# }
# #T_8753c_row0_col3 {
#   background-color: #f4b7f5;
#   color: #000000;
# }
# #T_8753c_row0_col4, #T_8753c_row0_col8 {
#   background-color: #00422b;
#   color: #f1f1f1;
# }
# #T_8753c_row0_col5 {
#   background-color: #fff500;
#   color: #000000;
# }
# #T_8753c_row0_col6, #T_8753c_row0_col9 {
#   background-color: #00fc54;
#   color: #000000;
# }
# #T_8753c_row1_col1, #T_8753c_row1_col3, #T_8753c_row2_col5, #T_8753c_row3_col2, #T_8753c_row3_col4, #T_8753c_row3_col6, #T_8753c_row3_col7, #T_8753c_row3_col8, #T_8753c_row3_col9 {
#   background-color: #000080;
#   color: #f1f1f1;
# }
# ...

# %%
result_df.to_csv('results.csv', index=None)

# %%
result_df.new_cases.plot();

# %%
result_df.set_index('date', inplace=True)

# %%
result_df
# Out:
#             new_cases  total_cases  new_deaths  total_deaths  new_tests
# date
# 2020-01-30        1.0          1.0           0             0        NaN  \
# 2020-01-31        4.0          5.0           0             0        NaN
# 2020-02-01        0.0          5.0           0             0        NaN
# 2020-02-02        NaN          NaN           0             0        NaN
# 2020-02-03        1.0          6.0           0             0        NaN
# ...               ...          ...         ...           ...        ...
# 2023-05-05     3611.0   44965043.0          36        531642        NaN
# 2023-05-06     2961.0   44968004.0          17        531659        NaN
# 2023-05-07     2380.0   44970384.0          21        531680        NaN
# 2023-05-08     1839.0   44972223.0          12        531692        NaN
# 2023-05-09     1331.0   44973554.0          15        531707        NaN
#
#             total_tests  cases_per_million  deaths_per_million
# date
# ...

# %%
result_df.loc['2020-09-01']
# Out:
# new_cases             6.992100e+04
# total_cases           3.691171e+06
# new_deaths            8.190000e+02
# total_deaths          6.528800e+04
# new_tests             1.016920e+06
# total_tests           4.318995e+07
# cases_per_million     2.674753e+03
# deaths_per_million    4.730999e+01
# tests_per_million     3.129696e+04
# Name: 2020-09-01 00:00:00, dtype: float64

# %%
result_df.new_cases.plot()
result_df.new_deaths.plot();

# %%
result_df.total_cases.plot()
result_df.total_deaths.plot();

# %%
death_rate = result_df.total_deaths / result_df.total_cases

# %%
death_rate.plot(title='Death Rate');

# %%
positive_rates = result_df.total_cases / result_df.total_tests
positive_rates.plot(title='Positive Rate');

# %%
covid_month_df.new_cases.plot(kind='bar');

# %%
covid_month_df.new_tests.plot(kind='bar');

# %%
covid_month_df.new_deaths.plot(kind = 'bar');

# %%
covid_df.style.background_gradient(cmap='twilight_shifted')
# Out:
# <style type="text/css">
# ...

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0    2020-01-30        1.0           0        NaN  2020      1   30        3  \
# 1    2020-01-31        4.0           0        NaN  2020      1   31        4
# 2    2020-02-01        0.0           0        NaN  2020      2    1        5
# 3    2020-02-02        NaN           0        NaN  2020      2    2        6
# 4    2020-02-03        1.0           0        NaN  2020      2    3        0
# ...         ...        ...         ...        ...   ...    ...  ...      ...
# 1191 2023-05-05     3611.0          36        NaN  2023      5    5        4
# 1192 2023-05-06     2961.0          17        NaN  2023      5    6        5
# 1193 2023-05-07     2380.0          21        NaN  2023      5    7        6
# 1194 2023-05-08     1839.0          12        NaN  2023      5    8        0
# 1195 2023-05-09     1331.0          15        NaN  2023      5    9        1
#
# ...

# %%
result_df.new_cases.plot();

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
result_df.new_cases.plot();

# %%
# Plot the data
plt.plot(result_df.new_cases)

# Add title and axis labels
plt.title('New Cases Over Time')
plt.xlabel('Date')
plt.ylabel('New Cases')

# Show the plot
plt.show()


# Set the plot style
sns.set_style("darkgrid")

# Plot the data
plt.rcParams['figure.figsize'] = [10, 5]
sns.lineplot(x=result_df.index, y=result_df.new_cases, color = 'red')

# Add title and axis labels
plt.title('New Cases Over Time')
plt.xlabel('Date')
plt.ylabel('New Cases')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create line chart for total case
sns.lineplot(data=result_df, x='date', y='total_cases', color = 'b', lw = 2, ls = '--', mew = 2, alpha = .8, mec = '+',   )

# Add line chart for total deaths
sns.lineplot(data=result_df, x='date', y='total_deaths',color = 'red', lw = 2, mew = 2, alpha = 1, mec = '+',   )

# Set chart title and axis labels
plt.title('Total Cases vs Total Deaths')
plt.xlabel('Date')
plt.ylabel('Count')

# Show the chart
plt.show()

# %%
sns.lineplot(data=death_rate, color = 'r')
plt.title('Death Rate', color ='r')
plt.show()
